# %% [markdown]
# <a href="https://colab.research.google.com/github/amicuscertus/Harbor001/blob/master/image001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import data, io, filters
from skimage.color import rgb2gray
import matplotlib.pyplot as plt
import numpy as np

# %%
image = io.imread('http://academia.rdy.jp/harbor/wp-content/uploads/2019/11/lalaland.jpg')
io.imshow(image)

# %%
print(type(image))
print(image.shape)
# Out:
# <class 'imageio.core.util.Array'>
# (353, 512, 3)

# %%
image_copy = np.copy(image)
image_copy[:, :, 0] = 0
io.imshow(image_copy)

# %%
image_copy = np.copy(image)
image_copy[:, :, 0] = 255
io.imshow(image_copy)

# %%
image_copy = np.copy(image)
reddish = image[:, :, 0] > 200
print(reddish.shape)
io.imshow(reddish)
# Out:
# (353, 512)

# %%
image_copy[reddish] = [255, 0, 255]
io.imshow(image_copy)

# %%
image_gray = rgb2gray(image)
io.imshow(image_gray)

# %%
red_multiplier = [1, 0, 0]
yellow_multiplier = [1, 1, 0]

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))
ax1.imshow(red_multiplier * image)
ax2.imshow(yellow_multiplier * image)
