# %% [markdown]
# <a href="https://colab.research.google.com/github/amicuscertus/Harbor001/blob/master/pandas001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = np.random.randint(low=0, high=100, size=(10, 4))
print(type(a))
print(a)
# Out:
# <class 'numpy.ndarray'>
# [[54 38 47 48]
#  [83 15  9 49]
#  [88 46 72 83]
#  [52  7 99 89]
#  [29 27 19 52]
#  [63 47 64 59]
#  [87 14 19  0]
#  [75 37 89 15]
#  [ 2 93 94 35]
#  [65 30 62 10]]

# %%
b = pd.DataFrame(a)
print(type(b))
print(b)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     0   1   2   3
# 0  54  38  47  48
# 1  83  15   9  49
# 2  88  46  72  83
# 3  52   7  99  89
# 4  29  27  19  52
# 5  63  47  64  59
# 6  87  14  19   0
# 7  75  37  89  15
# 8   2  93  94  35
# 9  65  30  62  10

# %%
print(b.columns)
print(b.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)
# RangeIndex(start=0, stop=10, step=1)

# %%
b.columns = ['c', 'python', 'java', 'swift']
b.index = ['alice', 'bob', 'cathy', 'dave', 'ed', 'frank',
           'george', 'henry', 'ida', 'jane']
print(b)
# Out:
#          c  python  java  swift
# alice   54      38    47     48
# bob     83      15     9     49
# cathy   88      46    72     83
# dave    52       7    99     89
# ed      29      27    19     52
# frank   63      47    64     59
# george  87      14    19      0
# henry   75      37    89     15
# ida      2      93    94     35
# jane    65      30    62     10

# %%
b.describe()
# Out:
#                c     python       java      swift
# count  10.000000  10.000000  10.000000  10.000000
# mean   59.800000  35.400000  57.400000  44.000000
# std    27.336585  24.391255  32.907952  29.608557
# min     2.000000   7.000000   9.000000   0.000000
# 25%    52.500000  18.000000  26.000000  20.000000
# 50%    64.000000  33.500000  63.000000  48.500000
# 75%    81.000000  44.000000  84.750000  57.250000
# max    88.000000  93.000000  99.000000  89.000000

# %%
sns.pairplot(b)

# %%
sns.scatterplot(x='c', y='python', hue='swift', data=b)

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print(iris.columns)
print(iris.index)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
# RangeIndex(start=0, stop=150, step=1)

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(b.columns)
print(b.index)
# Out:
# Index(['c', 'python', 'java', 'swift'], dtype='object')
# Index(['alice', 'bob', 'cathy', 'dave', 'ed', 'frank', 'george', 'henry',
#        'ida', 'jane'],
#       dtype='object')

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris, hue='species')

# %%
sns.scatterplot(x='sepal_length', y='petal_length', hue='species', data=iris)
