# %% [markdown]
# <a href="https://colab.research.google.com/github/amicuscertus/Harbor001/blob/master/scrape1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests
# !pip install beautifulsoup4

# %%
import numpy as np
import pandas as pd
import requests
import bs4
import lxml.etree as xml

# %%
URL = "https://www.kobegakuin.ac.jp/information/public/teacher/pharmacy/fujii.html"
requests.get(URL)
# Out:
# <Response [200]>

# %%
web_page = bs4.BeautifulSoup(requests.get(URL, {}).content, "html.parser")
web_page
# Out:
# <!DOCTYPE html>
#
# <html lang="ja">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#">
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" id="viewport" name="viewport"/>
# <script src="/js/viewport.js"></script>
# <title>藤井　文彦｜薬学部｜教員総覧｜情報の公表｜大学紹介｜神戸学院大学</title>
# <meta content="神戸学院大学公式サイト。入試情報、大学紹介、学部・大学院、教育・研究、学生生活、、国際交流、社会連携、就職支援・キャリアサポートなど。" name="description"/>
# <meta content="神戸学院大学,神戸学院,KOBE GAKUIN UNIVERSITY,ポートアイランド,有瀬,大学紹介,学部・大学院,教育・研究,学生生活,国際交流,社会連携,就職支援・キャリアサポート" name="keywords"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/css/common.css" rel="stylesheet"/>
# <link href="/css/style.css" rel="stylesheet"/>
# <link href="/css/style_add.css" rel="stylesheet"/>
# <script src="/js/analytics.js"></script>
# ...
